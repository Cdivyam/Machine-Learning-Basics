# %% [markdown]
# <a href="https://colab.research.google.com/github/Cdivyam/Machine-Learning-Basics/blob/ccpp-sklearn/LinearRegression/Notebooks/CCPP_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('/content/CCPP.xlsx')
print(df.head(5))
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
df.columns
# Out:
# Index(['AT', 'V', 'AP', 'RH', 'PE'], dtype='object')

# %%
X = df[['AT', 'V', 'AP', 'RH']]
Y = df['PE']

print(X.head(5))
print(Y.head(5))
# Out:
#       AT      V       AP     RH
# 0  14.96  41.76  1024.07  73.17
# 1  25.18  62.96  1020.04  59.08
# 2   5.11  39.40  1012.16  92.14
# 3  20.86  57.32  1010.24  76.64
# 4  10.82  37.50  1009.23  96.62
# 0    463.26
# 1    444.37
# 2    488.56
# 3    446.48
# 4    473.90
# Name: PE, dtype: float64

# %%
sns.set()
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression as LR
reg = LR()
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.score(X_train, y_train)
# Out:
# 0.9277810622495642

# %%
y_preds = reg.predict(X_test)

# %%
reg.score(X_test, y_test)
# Out:
# 0.9323516674165115

# %%
diff = y_preds-y_test

# %%
np.sum(diff)
# Out:
# 184.0117448770891

# %%
diff
# Out:
# 6167    -7.334220
# 8395     3.170255
# 6736     6.700134
# 919     -5.238420
# 3099     3.167370
# 5735    -0.507989
# 1134    -1.538643
# 7456    13.232267
# 4012    -9.469029
# 6850     2.236215
# 3799    -2.327033
# 4189    -1.314090
# 8931     5.268392
# 69      -1.110477
# 739     -0.961651
# 875      5.115204
# 1460    -0.955782
# 3674    -0.787926
# 8236    -7.227961
# 6729     7.807093
# 8660     2.369600
# 688      0.566759
# 7859    -2.716137
# 6899     1.029505
# 6923    -4.205033
# 7031    -1.403955
# 5037     2.719940
# 8998     1.595224
# 9131    -7.494228
# 1811     1.290949
#           ...
# 4244     1.175663
# 6967    -2.987735
# 569     -3.477607
# 4987     8.585225
# 5030     1.975714
# 2938     0.627310
# 4523     5.930637
# 6191    -7.460538
# 7301    -8.397587
# 5194     2.928317
# 2788    -5.447751
# 6320    -7.533131
# 6639    -5.587554
# 2646     4.009616
# 179      3.479478
# 6815     0.718801
# 1486    -0.740338
# 7400    -1.700085
# 3151    -6.583446
# ...

# %%
(1/1914)*(np.sum(diff))
# Out:
# 0.0961398876055847
